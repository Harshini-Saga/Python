# %%
from abc import ABC,abstractmethod
class Mobile(ABC):
    @abstractmethod
    def RAM(self):
        pass
    @abstractmethod
    def ROM(self):
        pass
    @abstractmethod
    def Battery(self):
        pass
    #concrete method
    def about_device(self):
        return "This is Mobile"
class oppo(Mobile):
    def __init__(self,model,oppo_ram,oppo_rom,oppo_battery):
        self.model=model
        self.oppo_ram=oppo_ram
        self.oppo_rom=oppo_rom
        self.oppo_battery=oppo_battery
    def RAM(self):
        return f"The Oppo {self.model} have {self.oppo_ram}GB RAM"
    def ROM(self):
        return f"The Oppo {self.model} have {self.oppo_rom}GB ROM"
    def Battery(self):
        return f"The Oppo {self.model} have {self.oppo_battery}MAH"
    def camera(self,front,back):
        return f"The Oppo {self.model} have {front}MP front camera + {back}MP back camera"
#m=Mobile() We cant instantiate for abstract class
o=oppo("Reno16",256,8,1000)
print(o.RAM())
print(o.Battery())
print(o.camera(54,89))
print(o.about_device())
# Out:
# The Oppo Reno16 have 256GB RAM
# The Oppo Reno16 have 1000MAH
# The Oppo Reno16 have 54MP front camera + 89MP back camera
# This is Mobile
