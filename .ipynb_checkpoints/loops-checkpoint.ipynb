# %%
n1=int(input())
n2=int(input())
n3=int(input())
if n1%2==0:
    print("even")
if n2%2==0:
    print("even")
if n3%2==0:
    print("even")
else:
    print("odd")
# Out:
#  10
#  3
#  7
# even
# odd
